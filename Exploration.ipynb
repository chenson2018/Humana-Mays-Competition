# %%
import pandas as pd
df = pd.read_csv('HMAHCC_COMP.csv')

# %%
df
# Out:
#                     id           event_descr  \
# 0        ID10010854159       RX Claim - Paid
# 1        ID10010854159       RX Claim - Paid
# 2        ID10010854159   RX Claim - Rejected
# 3        ID10010854159       RX Claim - Paid
# 4        ID10010854159       RX Claim - Paid
# 5        ID10010854159       RX Claim - Paid
# 6        ID10010854159       RX Claim - Paid
# 7        ID10010854159      Fully Paid Claim
# 8        ID10010854159   RX Claim - New Drug
# 9        ID10010854159       RX Claim - Paid
# 10       ID10010854159   Inbound Call by Mbr
# 11       ID10010854159  Inbound Call by Prov
# 12       ID10010854159   Inbound Call by Mbr
# 13       ID10010854159   Inbound Call by Mbr
# 14       ID10010854159   Inbound Call by Mbr
# 15       ID10010854159       RX Claim - Paid
# 16       ID10010854159       RX Claim - Paid
# 17       ID10010854159      Fully Paid Claim
# 18       ID10010854159      Fully Paid Claim
# 19       ID10010854159   RX Claim - Rejected
# ...
